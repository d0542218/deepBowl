# %%
from flask import Flask, request, make_response, jsonify, Response
from flask_restful import Resource,Api
from flask_cors import CORS
import collections
import json

# %%
import pymysql # 連接 MySQL 資料庫
#db = pymysql.connect("13.230.161.175", port=3306, user='public-root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')

# %%
app = Flask(__name__)
api = Api(app)
CORS(app)

class gameByType(Resource):
    def get(self, type_id):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game, game_has_type WHERE game.game_ID = game_has_type.game_ID AND game_has_type.type_ID = %s"
        db.ping(reconnect=True)
        cursor.execute(sql, type_id);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8], 'type_ID': row[10]}
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByName(Resource):
    def get(self, name):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game WHERE game_name LIKE %s"
        db.ping(reconnect=True)
        cursor.execute(sql, ("%" + name + "%"));
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8]}
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByCompany(Resource):
    def get(self, name):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM company, company_has_game, game where game.game_ID = company_has_game.game_ID\
            and company_has_game.company_ID = company.company_ID and company.company_name = %s"
        db.ping(reconnect=True)
        cursor.execute(sql, name);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'company_ID': row[0], 'company_name': row[1], 'game_Id': row[3], 'game_name': row[6], 
                 'game_introduction': row[7], 'game_price': str(row[8]), 'game_price_currency': row[9], 'game_store_URL': row[10],
                 'game_score': row[11], 'game_release_date': str(row[12])}
#             d['game_id'] = row[0]
#             d['company_name'] = row[1]
#             d['game_name'] = row[2]
#             d['game_introduction'] = row[3]
#             d['game_price'] = str(row[4])
#             d['game_score'] = row[5]
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByLatest(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game WHERE game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8]}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByPopular(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game WHERE game_score = '壓倒性好評' AND game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8]}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByFree(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game, type, game_has_type WHERE type.type_name = '免費'\
        AND type.type_ID = game_has_type.type_ID AND game_has_type.game_ID = game.game_ID AND game_price = 0\
        AND game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8], 'type_ID': row[9], 'type_name': row[10],}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByAction(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game, type, game_has_type WHERE type.type_name = '動作'\
        AND type.type_ID = game_has_type.type_ID AND game_has_type.game_ID = game.game_ID\
        AND game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8], 'type_ID': row[9], 'type_name': row[10],}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByAdventure(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game, type, game_has_type WHERE type.type_name = '冒險'\
        AND type.type_ID = game_has_type.type_ID AND game_has_type.game_ID = game.game_ID\
        AND game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8], 'type_ID': row[9], 'type_name': row[10],}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByCharacter(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game, type, game_has_type WHERE type.type_name = '角色扮演'\
        AND type.type_ID = game_has_type.type_ID AND game_has_type.game_ID = game.game_ID AND game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8], 'type_ID': row[9], 'type_name': row[10],}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')
    
class gameByStrategy(Resource):
    def get(self, date):
        db = pymysql.connect('usefordeepbowl.cukfiecfgfog.ap-northeast-1.rds.amazonaws.com', port=3306, user='public_root', passwd='thisisasamplepassword', db='game_chatbot', charset='utf8')
        cursor = db.cursor()
        sql="SELECT * FROM game, type, game_has_type WHERE type.type_name = '策略'\
        AND type.type_ID = game_has_type.type_ID AND game_has_type.game_ID = game.game_ID AND game_release_date >= %s"
        db.ping(reconnect=True)
        cursor.execute(sql, date);
        db.commit()
        data = cursor.fetchall()
        
        objects_list = []
        for row in data:
            d = collections.OrderedDict() #有序的字典
            d = {'game_ID': row[0], 'game_name': row[1], 'game_introduction': row[2], 'game_price': str(row[3]),
               'game_price_currency':row [4], 'game_store_URL': row[5], 'game_score': row[6], 'game_release_date': str(row[7])
               , 'game_guides_URL': row[8], 'type_ID': row[9], 'type_name': row[10],}
            
            objects_list.append(d)
        j = json.dumps(objects_list)  #將 Python對象編碼成 JSON 字符串
        return Response(j, mimetype='application/json')

api.add_resource(gameByType, '/game/type/<string:type_id>')
api.add_resource(gameByName, '/game/name/<string:name>')
api.add_resource(gameByCompany, '/game/company/<string:name>')
api.add_resource(gameByLatest, '/game/latest/<string:date>')
api.add_resource(gameByPopular, '/game/popular/<string:date>')
api.add_resource(gameByFree, '/game/free/<string:date>')
api.add_resource(gameByAction, '/game/action/<string:date>')
api.add_resource(gameByAdventure, '/game/adventure/<string:date>')
api.add_resource(gameByCharacter, '/game/character/<string:date>')
api.add_resource(gameByStrategy, '/game/strategy/<string:date>')

if __name__ == '__main__':
    app.run(port=9660)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:9660/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Dec/2018 10:41:25] "GET /game/type/25 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:25] "GET /game/popular/2018-05-01 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:25] "GET /game/latest/2018-11-01 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:25] "GET /game/free/2015-01-01 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:25] "GET /game/action/2017-01-01 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:25] "GET /game/adventure/2017-01-01 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:26] "GET /game/strategy/2017-01-01 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Dec/2018 10:41:31] "GET /game/character/2017-01-01 HTTP/1.1" 200 -
# ...
