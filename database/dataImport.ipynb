# %%
import pymysql
import json
import re

# %%
connect = pymysql.connect("13.230.161.175","public-root","thisisasamplepassword","game_chatbot")
# connect = pymysql.connect("140.134.241.171","hidochunk","**********","game_chatbot")

# %%
with open('Steam1201.json') as json_data:
    data = json.load(json_data)

# %%
cursor = connect.cursor()

# %%
gameTypeAlreadyHave = {}
gameDevelopeCompanyAlreadyHave = {}

for col in data:
    gameName = col["遊戲名稱"]
    gamePrice = col["價錢"]
    gameIntroduction = col["遊戲介紹"]
    gameNearlyScore = col["最近評論"]
    gameTotalScore = col["所有評論"]
    gameReleaseDate = col["發行日期"]
    gameDevelopeCompany = col["公司"]
    gameType = col["標籤"]
    gameLinkURL = col["連結"]

#     評價
    if gameNearlyScore not in ["壓倒性負評","極度負評","大多負評","負評","褒貶不一","好評","大多好評","極度好評","壓倒性好評"]:
        if gameTotalScore not in ["壓倒性負評","極度負評","大多負評","負評","褒貶不一","好評","大多好評","極度好評","壓倒性好評"]:
            gameScore = "NULL"
        else:
            gameScore = gameTotalScore
    else:
        gameScore = gameNearlyScore
        
#     價格
    if "免費" not in gamePrice:
        priceCut = gamePrice.split()
        if priceCut[0] == "NT$":
            gamePriceCurrency = "TWD"
        gamePriceNum = int(priceCut[1].replace(',',''))
    else:
        gamePriceNum = 0
        gamePriceCurrency = "TWD"

    
#     發布日期
    gameReleaseDateCut = gameReleaseDate.split()
    gameReleaseDateYear = gameReleaseDateCut[0]
    gameReleaseDateMonth = gameReleaseDateCut[2]
    gameReleaseDateDay = gameReleaseDateCut[4]
    gameReleaseDateParsed = gameReleaseDateYear+"-"+gameReleaseDateMonth+"-"+gameReleaseDateDay
    
    
    inputValueString = "'"+re.escape(gameName).strip()+"','"+re.escape(gameIntroduction).strip()+"',"+str(gamePriceNum)+",'"+gamePriceCurrency+"','"+gameLinkURL+"','"+gameReleaseDateParsed+"'"
    if gameScore == "NULL":
        inputValueString = inputValueString + ",NULL"
    else:
        inputValueString = inputValueString + ",'" + gameScore +"'"
        
#     game table INSETR
    print("INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ("+inputValueString+");")
    print()
    cursor.execute("INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES (" + inputValueString + ");")
    connect.commit()   
    
    cursor.execute("SELECT @@IDENTITY;")
    gameIDs = cursor.fetchall()
    gameID = gameIDs[0][0]
    
#     標籤
    gameTypeList = gameType.split(",")
    gameTypeList = list(set(gameTypeList))
    for gametype in gameTypeList:
        gametype = gametype.strip()
        if gametype not in gameTypeAlreadyHave:
            print("INSERT INTO type(type_name) VALUES ('"+gametype+"');")
            cursor.execute("INSERT INTO type(type_name) VALUES ('"+gametype+"');")
            connect.commit()
            cursor.execute("SELECT @@IDENTITY;")
            gametypeID = cursor.fetchall()
            gameTypeAlreadyHave[gametype] = gametypeID[0][0]
        print(gameID,",",gameTypeAlreadyHave[gametype])
        cursor.execute("INSERT INTO game_has_type(game_ID,type_ID) VALUES ("+str(gameID)+","+str(gameTypeAlreadyHave[gametype])+");")

#     廠商
    gameDevelopeCompanyList = gameDevelopeCompany.split(",")
    gameDevelopeCompanyList = list(set(gameDevelopeCompanyList))
    for gamedevelopecompany in gameDevelopeCompanyList:
        gamedevelopecompany = gamedevelopecompany.strip()
        if gamedevelopecompany not in gameDevelopeCompanyAlreadyHave:    
            print("INSERT INTO company(company_name) VALUES ('"+gamedevelopecompany+"');")
            cursor.execute("INSERT INTO company(company_name) VALUES ('"+gamedevelopecompany+"');")
            connect.commit()
            cursor.execute("SELECT @@IDENTITY;")
            results = cursor.fetchall()
            gameDevelopeCompanyAlreadyHave[gamedevelopecompany] = results[0][0]
        cursor.execute("INSERT INTO company_has_game(game_ID,company_ID) VALUES ("+str(gameID)+","+str(gameDevelopeCompanyAlreadyHave[gamedevelopecompany])+");")
    
    print(gameName+", "+gamePriceCurrency+str(gamePriceNum)+", "+gameScore)
    print(gameLinkURL)
    print(gameDevelopeCompanyList)
    print(gameTypeList)
    print(gameReleaseDateParsed)
    print()
                       
print(gameTypeAlreadyHave)
print(gameDevelopeCompanyAlreadyHave)
connect.close()
# Out:
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('STEINS\;GATE','\由5pb\.\和nitroplus\共\同\開\發\的\《STEINS\;GATE\》\曾\被Famitsu\雜\誌\授\予\年\度\優\秀\遊\戲\獎\項\，\並\在Famitsu\讀\者\調\查\中\被\評\為\最\煽\情\的\“\催\淚\遊\戲\”\。\如\此\扣\人\心\弦\的\視\覺\小\說\遊\戲\，\現\已\被\改\編\為\漫\畫\、\動\畫\及\動\畫\電\影\等\。',670,'TWD','https://store.steampowered.com/app/412830/STEINSGATE/?snr=1_7_7_230_150_4','2016-9-8','壓倒性好評');
#
# INSERT INTO type(type_name) VALUES ('單人');
# 1 , 1
# INSERT INTO type(type_name) VALUES ('驚悚');
# 1 , 2
# INSERT INTO type(type_name) VALUES ('休閒');
# 1 , 3
# INSERT INTO type(type_name) VALUES ('劇情豐富');
# 1 , 4
# INSERT INTO type(type_name) VALUES ('戀愛模擬');
# 1 , 5
# INSERT INTO type(type_name) VALUES ('冒險');
# 1 , 6
# INSERT INTO type(type_name) VALUES ('時光旅行');
# 1 , 7
# INSERT INTO type(type_name) VALUES ('懸疑');
# 1 , 8
# INSERT INTO type(type_name) VALUES ('恐怖');
# 1 , 9
# INSERT INTO type(type_name) VALUES ('愛情');
# 1 , 10
# INSERT INTO type(type_name) VALUES ('懸疑驚悚');
# 1 , 11
# INSERT INTO type(type_name) VALUES ('日本動畫');
# 1 , 12
# INSERT INTO type(type_name) VALUES ('科學');
# 1 , 13
# INSERT INTO type(type_name) VALUES ('氛圍');
# 1 , 14
# INSERT INTO type(type_name) VALUES ('多結局');
# 1 , 15
# INSERT INTO type(type_name) VALUES ('好評原聲帶');
# 1 , 16
# INSERT INTO type(type_name) VALUES ('網路爆紅');
# 1 , 17
# INSERT INTO type(type_name) VALUES ('選擇導向');
# 1 , 18
# INSERT INTO type(type_name) VALUES ('視覺小說');
# 1 , 19
# INSERT INTO type(type_name) VALUES ('科幻');
# 1 , 20
# INSERT INTO company(company_name) VALUES ('Spike Chunsoft Co.');
# INSERT INTO company(company_name) VALUES ('Ltd.');
# STEINS;GATE, TWD670, 壓倒性好評
# https://store.steampowered.com/app/412830/STEINSGATE/?snr=1_7_7_230_150_4
# ['Spike Chunsoft Co.', ' Ltd.']
# ['單人', '驚悚', '休閒', '劇情豐富', '戀愛模擬', '冒險', '時光旅行', '懸疑', '恐怖', '愛情', '懸疑驚悚', '日本動畫', '科學', '氛圍', '多結局', '好評原聲帶', '網路爆紅', '選擇導向', '視覺小說', '科幻']
# 2016-9-8
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('House\ Flipper','\《\房\產\達\人\》\是\個\能\讓\你\成\為\一\人\房\屋\翻\新\團\隊\的\獨\特\機\會\。\購\買\、\整\修\、\升\級\破\損\的\房\屋\，\賦\予\它\們\新\的\生\命\，\並\以\更\高\的\價\格\賣\出\！',318,'TWD','https://store.steampowered.com/app/613100/House_Flipper/?snr=1_7_7_230_150_4','2018-5-17','極度好評');
#
# INSERT INTO type(type_name) VALUES ('建造');
# 2 , 21
# INSERT INTO type(type_name) VALUES ('模擬');
# 2 , 22
# INSERT INTO type(type_name) VALUES ('擬真');
# 2 , 23
# INSERT INTO type(type_name) VALUES ('放鬆');
# 2 , 24
# INSERT INTO type(type_name) VALUES ('策略');
# 2 , 25
# 2 , 3
# INSERT INTO type(type_name) VALUES ('管理');
# 2 , 26
# INSERT INTO type(type_name) VALUES ('毀滅');
# 2 , 27
# INSERT INTO type(type_name) VALUES ('經濟');
# 2 , 28
# INSERT INTO type(type_name) VALUES ('沙盒');
# 2 , 29
# INSERT INTO type(type_name) VALUES ('教育學習');
# 2 , 30
# INSERT INTO type(type_name) VALUES ('基地建設');
# 2 , 31
# INSERT INTO type(type_name) VALUES ('闔家');
# 2 , 32
# INSERT INTO type(type_name) VALUES ('虛擬實境');
# 2 , 33
# INSERT INTO type(type_name) VALUES ('設計及繪圖');
# 2 , 34
# INSERT INTO type(type_name) VALUES ('獨立');
# 2 , 35
# INSERT INTO type(type_name) VALUES ('多人');
# 2 , 36
# 2 , 1
# INSERT INTO type(type_name) VALUES ('第一人稱視角');
# 2 , 37
# 2 , 17
# INSERT INTO company(company_name) VALUES ('Frozen District');
# INSERT INTO company(company_name) VALUES ('PlayWay S.A.');
# House Flipper, TWD318, 極度好評
# https://store.steampowered.com/app/613100/House_Flipper/?snr=1_7_7_230_150_4
# ['Frozen District', ' PlayWay S.A.']
# ['建造', '模擬', '擬真', '放鬆', '策略', '休閒', '管理', '毀滅', '經濟', '沙盒', '教育學習', '基地建設', '闔家', '虛擬實境', '設計及繪圖', '獨立', '多人', '單人', '第一人稱視角', '網路爆紅']
# 2018-5-17
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Fallout\ 4','\以\《\異\塵\餘\生3\》\、\《\上\古\卷\軸V\：\無\界\天\際\》\等\作\品\奪\獎\的\ Bethesda\ Game\ Studios\，\邀\您\進\入\《\異\塵\餘\生4\》\的\世\界\，\體\驗\ Bethesda\ \最\具\雄\心\壯\志\的\鉅\作\，\享\受\新\一\代\的\開\放\世\界\遊\戲\。',970,'TWD','https://store.steampowered.com/app/377160/Fallout_4/?snr=1_7_7_230_150_4','2015-11-10','極度好評');
#
# INSERT INTO type(type_name) VALUES ('第三人稱視角');
# 3 , 38
# INSERT INTO type(type_name) VALUES ('第三人稱射擊');
# 3 , 39
# INSERT INTO type(type_name) VALUES ('探索');
# 3 , 40
# 3 , 16
# INSERT INTO type(type_name) VALUES ('角色扮演');
# 3 , 41
# 3 , 4
# 3 , 3
# 3 , 6
# 3 , 29
# INSERT INTO type(type_name) VALUES ('開放世界');
# 3 , 42
# INSERT INTO type(type_name) VALUES ('第一人稱射擊');
# 3 , 43
# INSERT INTO type(type_name) VALUES ('末日');
# 3 , 44
# INSERT INTO type(type_name) VALUES ('射擊');
# 3 , 45
# 3 , 14
# INSERT INTO type(type_name) VALUES ('生存');
# 3 , 46
# 3 , 1
# 3 , 37
# INSERT INTO type(type_name) VALUES ('動作');
# 3 , 47
# INSERT INTO type(type_name) VALUES ('動作角色扮演');
# 3 , 48
# 3 , 20
# INSERT INTO company(company_name) VALUES ('Bethesda Softworks');
# Fallout 4, TWD970, 極度好評
# https://store.steampowered.com/app/377160/Fallout_4/?snr=1_7_7_230_150_4
# ['Bethesda Softworks']
# ['第三人稱視角', '第三人稱射擊', '探索', '好評原聲帶', '角色扮演', '劇情豐富', '休閒', '冒險', '沙盒', '開放世界', '第一人稱射擊', '末日', '射擊', '氛圍', '生存', '單人', '第一人稱視角', '動作', '動作角色扮演', '科幻']
# 2015-11-10
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('MOBIUS\ FINAL\ FANTASY\™','\《MOBIUS\ FINAL\ FANTASY\》\是\以\負\責\無\數FF\系\列\『FINAL\ FANTASY\ VII\』\『FINAL\ FANTASYXIII\』\的\北\瀨\佳\範\為\中\心\，\與\公\司\內\部\負\責\的\開\發\「FINAL\ FANTASY\」\系\列\的\夥\伴\們\所\製\作\的\高\質\量RPG\手\機\遊\戲\。',0,'TWD','https://store.steampowered.com/app/536930/MOBIUS_FINAL_FANTASY/?snr=1_7_7_230_150_4','2017-2-6','極度好評');
#
# INSERT INTO type(type_name) VALUES ('奇幻');
# 4 , 49
# INSERT INTO type(type_name) VALUES ('回合制戰鬥');
# 4 , 50
# INSERT INTO type(type_name) VALUES ('回合制');
# 4 , 51
# INSERT INTO type(type_name) VALUES ('日系角色扮演');
# 4 , 52
# 4 , 41
# 4 , 3
# 4 , 4
# 4 , 6
# 4 , 46
# 4 , 42
# INSERT INTO type(type_name) VALUES ('自創角色');
# 4 , 53
# INSERT INTO type(type_name) VALUES ('MMORPG');
# 4 , 54
# INSERT INTO type(type_name) VALUES ('卡牌');
# 4 , 55
# 4 , 43
# 4 , 12
# INSERT INTO type(type_name) VALUES ('免費');
# 4 , 56
# 4 , 36
# 4 , 1
# 4 , 47
# 4 , 48
# INSERT INTO company(company_name) VALUES ('Square Enix');
# MOBIUS FINAL FANTASY™, TWD0, 極度好評
# https://store.steampowered.com/app/536930/MOBIUS_FINAL_FANTASY/?snr=1_7_7_230_150_4
# ['Square Enix']
# ['奇幻', '回合制戰鬥', '回合制', '日系角色扮演', '角色扮演', '休閒', '劇情豐富', '冒險', '生存', '開放世界', '自創角色', 'MMORPG', '卡牌', '第一人稱射擊', '日本動畫', '免費', '多人', '單人', '動作', '動作角色扮演']
# 2017-2-6
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Assassin\'s\ Creed\®\ Origins','\《ASSASSIN\'S\ CREED\®\ ORIGINS\》\是\嶄\新\的\開\始\ \*Discovery\ Tour\ by\ Assassin\'s\ Creed\®\:\ Ancient\ Egypt\ \發\現\之\旅\ \現\已\透\過\免\費\更\新\的\方\式\推\出\*\ \充\滿\王\權\角\力\與\陰\謀\詭\計\的\古\埃\及\時\代\，\正\在\權\力\的\殘\酷\鬥\爭\下\逐\漸\消\失\。\回\到\刺\客\兄\弟\會\的\緣\起\時\刻\，\揭\開\黑\暗\秘\辛\和\早\已\被\世\人\遺\忘\的\神\話\。',1620,'TWD','https://store.steampowered.com/app/582160/Assassins_Creed_Origins/?snr=1_7_7_230_150_4','2017-10-26','極度好評');
#
# INSERT INTO type(type_name) VALUES ('搶劫');
# 5 , 57
# 5 , 40
# 5 , 16
# INSERT INTO type(type_name) VALUES ('步行模擬');
# 5 , 58
# 5 , 41
# 5 , 4
# INSERT INTO type(type_name) VALUES ('光明會');
# 5 , 59
# 5 , 6
# 5 , 29
# INSERT INTO type(type_name) VALUES ('暗殺');
# 5 , 60
# 5 , 42
# INSERT INTO type(type_name) VALUES ('歷史');
# 5 , 61
# INSERT INTO type(type_name) VALUES ('潛行');
# 5 , 62
# INSERT INTO type(type_name) VALUES ('跑酷');
# 5 , 63
# 5 , 14
# 5 , 36
# 5 , 1
# 5 , 47
# 5 , 48
# 5 , 38
# INSERT INTO company(company_name) VALUES ('Ubisoft');
# Assassin's Creed® Origins, TWD1620, 極度好評
# https://store.steampowered.com/app/582160/Assassins_Creed_Origins/?snr=1_7_7_230_150_4
# ['Ubisoft']
# ['搶劫', '探索', '好評原聲帶', '步行模擬', '角色扮演', '劇情豐富', '光明會', '冒險', '沙盒', '暗殺', '開放世界', '歷史', '潛行', '跑酷', '氛圍', '多人', '單人', '動作', '動作角色扮演', '第三人稱視角']
# 2017-10-26
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Jurassic\ World\ Evolution','\身\臨\其\境\地\沉\浸\在\侏\羅\紀\系\列\的\舞\臺\中\，\打\造\您\自\己\的\侏\羅\紀\世\界\。\這\些\透\過\生\物\工\程\打\造\的\恐\龍\擁\有\高\度\智\慧\，\能\夠\對\周\遭\的\環\境\進\行\思\考\、\感\知\，\並\作\出\反\應\。\而\在\這\個\未\知\的\世\界\裡\，\生\命\總\會\找\到\自\己\的\出\路\。\同\時\您\還\要\面\對\商\業\間\諜\活\動\、\展\品\出\逃\，\以\及\破\壞\性\的\熱\帶\風\暴\帶\來\的\威\脅\。',1600,'TWD','https://store.steampowered.com/app/648350/Jurassic_World_Evolution/?snr=1_7_7_230_150_4','2018-6-12','極度好評');
#
# 6 , 20
# 6 , 21
# 6 , 22
# INSERT INTO type(type_name) VALUES ('暴力');
# 6 , 64
# 6 , 36
# 6 , 16
# 6 , 25
# 6 , 26
# 6 , 3
# INSERT INTO type(type_name) VALUES ('恐龍');
# 6 , 65
# 6 , 6
# 6 , 29
# 6 , 42
# 6 , 28
# INSERT INTO type(type_name) VALUES ('資源管理');
# 6 , 66
# 6 , 14
# 6 , 46
# 6 , 1
# 6 , 47
# INSERT INTO type(type_name) VALUES ('城市營造');
# 6 , 67
# INSERT INTO company(company_name) VALUES ('Frontier Developments');
# Jurassic World Evolution, TWD1600, 極度好評
# https://store.steampowered.com/app/648350/Jurassic_World_Evolution/?snr=1_7_7_230_150_4
# ['Frontier Developments']
# ['科幻', '建造', '模擬', '暴力', '多人', '好評原聲帶', '策略', '管理', '休閒', '恐龍', '冒險', '沙盒', '開放世界', '經濟', '資源管理', '氛圍', '生存', '單人', '動作', '城市營造']
# 2018-6-12
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Mirror','\這\是\一\款\“\美\少\女\＋\寶\石\消\除\＋GALGAME\”\結\合\的\遊\戲\。\你\在\异\世\界\里\邂\逅\各\种\各\样\的\美\女\，\与\她\们\战\斗\时\你\套\路\深\似\海\。\这\些\自\認\高\貴\的\盜\賊\精\靈\，\優\柔\寡\斷\的\龍\女\僕\，\喜\歡\著\同\性\的\女\王\，\圈\養\面\首\的\森\林\女\獵\手\都\被\你\不\擇\手\段\地\一\一\捕\獲\并\进\行\令\人\窒\息\的\操\作\～',45,'TWD','https://store.steampowered.com/app/644560/Mirror/?snr=1_7_7_230_150_4','2018-4-19','壓倒性好評');
#
# INSERT INTO type(type_name) VALUES ('搶先體驗');
# 7 , 68
# INSERT INTO type(type_name) VALUES ('色情內容');
# 7 , 69
# INSERT INTO type(type_name) VALUES ('可愛');
# 7 , 70
# INSERT INTO type(type_name) VALUES ('三消');
# 7 , 71
# INSERT INTO type(type_name) VALUES ('成人');
# 7 , 72
# 7 , 41
# INSERT INTO type(type_name) VALUES ('女主人翁');
# 7 , 73
# 7 , 5
# 7 , 4
# INSERT INTO type(type_name) VALUES ('裸露');
# 7 , 74
# 7 , 52
# 7 , 6
# INSERT INTO type(type_name) VALUES ('解謎');
# 7 , 75
# INSERT INTO type(type_name) VALUES ('工作場所不宜');
# 7 , 76
# 7 , 11
# 7 , 12
# 7 , 35
# 7 , 1
# 7 , 43
# 7 , 19
# INSERT INTO company(company_name) VALUES ('Paradise Project');
# Mirror, TWD45, 壓倒性好評
# https://store.steampowered.com/app/644560/Mirror/?snr=1_7_7_230_150_4
# ['Paradise Project']
# ['搶先體驗', '色情內容', '可愛', '三消', '成人', '角色扮演', '女主人翁', '戀愛模擬', '劇情豐富', '裸露', '日系角色扮演', '冒險', '解謎', '工作場所不宜', '懸疑驚悚', '日本動畫', '獨立', '單人', '第一人稱射擊', '視覺小說']
# 2018-4-19
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('RimWorld','A\ sci\-fi\ colony\ sim\ driven\ by\ an\ intelligent\ AI\ storyteller\.\ Inspired\ by\ Dwarf\ Fortress\ and\ Firefly\.\ Generates\ stories\ by\ simulating\ psychology\,\ ecology\,\ gunplay\,\ melee\ combat\,\ climate\,\ biomes\,\ diplomacy\,\ interpersonal\ relationships\,\ art\,\ medicine\,\ trade\,\ and\ more\.',498,'TWD','https://store.steampowered.com/app/294100/RimWorld/?snr=1_7_7_230_150_4','2018-10-17','壓倒性好評');
#
# 8 , 21
# 8 , 22
# INSERT INTO type(type_name) VALUES ('工藝');
# 8 , 77
# 8 , 68
# INSERT INTO type(type_name) VALUES ('太空');
# 8 , 78
# 8 , 16
# 8 , 25
# 8 , 26
# INSERT INTO type(type_name) VALUES ('可製作模組');
# 8 , 79
# INSERT INTO type(type_name) VALUES ('2D');
# 8 , 80
# 8 , 31
# 8 , 29
# 8 , 42
# INSERT INTO type(type_name) VALUES ('像素風格');
# 8 , 81
# 8 , 35
# 8 , 46
# 8 , 1
# 8 , 47
# 8 , 14
# 8 , 20
# INSERT INTO company(company_name) VALUES ('Ludeon Studios');
# RimWorld, TWD498, 壓倒性好評
# https://store.steampowered.com/app/294100/RimWorld/?snr=1_7_7_230_150_4
# ['Ludeon Studios']
# ['建造', '模擬', '工藝', '搶先體驗', '太空', '好評原聲帶', '策略', '管理', '可製作模組', '2D', '基地建設', '沙盒', '開放世界', '像素風格', '獨立', '生存', '單人', '動作', '氛圍', '科幻']
# 2018-10-17
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Mafia\ II','Vito\ Scaletta\ has\ started\ to\ make\ a\ name\ for\ himself\ on\ the\ streets\ of\ Empire\ Bay\ as\ someone\ who\ can\ be\ trusted\ to\ get\ a\ job\ done\.\ Together\ with\ his\ buddy\ Joe\,\ he\ is\ working\ to\ prove\ himself\ to\ the\ Mafia\,\ quickly\ escalating\ up\ the\ family\ ladder\ with\ crimes\ of\ larger\ reward\,\ status\ and\ consequence\…\ the\ life\ as\ a\ wise\ guy\ isn\’t\ quite\ as\.\.\.',688,'TWD','https://store.steampowered.com/app/50130/Mafia_II/?snr=1_7_7_230_150_4','2011-3-22','壓倒性好評');
#
# INSERT INTO type(type_name) VALUES ('美國');
# 9 , 82
# 9 , 39
# INSERT INTO type(type_name) VALUES ('駕駛');
# 9 , 83
# 9 , 16
# 9 , 41
# 9 , 4
# INSERT INTO type(type_name) VALUES ('3D 視覺');
# 9 , 84
# 9 , 6
# INSERT INTO type(type_name) VALUES ('經典');
# 9 , 85
# 9 , 42
# 9 , 74
# 9 , 29
# 9 , 45
# 9 , 14
# 9 , 36
# 9 , 1
# 9 , 47
# INSERT INTO type(type_name) VALUES ('犯罪');
# 9 , 86
# INSERT INTO type(type_name) VALUES ('音樂');
# 9 , 87
# 9 , 38
# INSERT INTO company(company_name) VALUES ('Feral Interactive (Mac)');
# INSERT INTO company(company_name) VALUES ('2K');
# Mafia II, TWD688, 壓倒性好評
# https://store.steampowered.com/app/50130/Mafia_II/?snr=1_7_7_230_150_4
# [' Feral Interactive (Mac)', '2K']
# ['美國', '第三人稱射擊', '駕駛', '好評原聲帶', '角色扮演', '劇情豐富', '3D 視覺', '冒險', '經典', '開放世界', '裸露', '沙盒', '射擊', '氛圍', '多人', '單人', '動作', '犯罪', '音樂', '第三人稱視角']
# 2011-3-22
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('BattleBlock\ Theater\®','Welcome\ to\ BattleBlock\ Theater\!\ You\’ve\ got\ no\ where\ to\ go\ but\ up\.\.\.on\ stage\.\ Play\ single\ player\ or\ co\-op\ to\ free\ your\ friends\ and\ save\ Hatty\ Hattington\!\ Jump\,\ solve\ and\ battle\ your\ way\ through\ a\ mysterious\ theater\ inhabited\ by\ highly\ technological\ felines\.',268,'TWD','https://store.steampowered.com/app/238460/BattleBlock_Theater/?snr=1_7_7_230_150_4','2014-5-15','壓倒性好評');
#
# INSERT INTO type(type_name) VALUES ('單機合作');
# 10 , 88
# 10 , 1
# INSERT INTO type(type_name) VALUES ('線上合作');
# 10 , 89
# INSERT INTO type(type_name) VALUES ('關卡編輯');
# 10 , 90
# INSERT INTO type(type_name) VALUES ('合作');
# 10 , 91
# 10 , 16
# INSERT INTO type(type_name) VALUES ('團隊導向');
# 10 , 92
# 10 , 3
# 10 , 80
# 10 , 6
# INSERT INTO type(type_name) VALUES ('傑作');
# 10 , 93
# 10 , 75
# INSERT INTO type(type_name) VALUES ('困難');
# 10 , 94
# INSERT INTO type(type_name) VALUES ('搞笑');
# 10 , 95
# 10 , 36
# INSERT INTO type(type_name) VALUES ('歡樂');
# 10 , 96
# INSERT INTO type(type_name) VALUES ('單機多人');
# 10 , 97
# 10 , 47
# INSERT INTO type(type_name) VALUES ('平台');
# 10 , 98
# 10 , 35
# INSERT INTO company(company_name) VALUES ('The Behemoth');
# BattleBlock Theater®, TWD268, 壓倒性好評
# https://store.steampowered.com/app/238460/BattleBlock_Theater/?snr=1_7_7_230_150_4
# ['The Behemoth']
# ['單機合作', '單人', '線上合作', '關卡編輯', '合作', '好評原聲帶', '團隊導向', '休閒', '2D', '冒險', '傑作', '解謎', '困難', '搞笑', '多人', '歡樂', '單機多人', '動作', '平台', '獨立']
# 2014-5-15
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Need\ For\ Speed\:\ Hot\ Pursuit','Become\ Seacrest\ County\'s\ top\ cop\ or\ most\ wanted\ racer\!',599,'TWD','https://store.steampowered.com/app/47870/Need_For_Speed_Hot_Pursuit/?snr=1_7_7_230_150_4','2010-11-16','極度好評');
#
# INSERT INTO type(type_name) VALUES ('大型多人連線');
# 11 , 99
# INSERT INTO type(type_name) VALUES ('競速');
# 11 , 100
# 11 , 22
# 11 , 83
# 11 , 16
# 11 , 91
# INSERT INTO type(type_name) VALUES ('重製');
# 11 , 101
# 11 , 89
# 11 , 23
# 11 , 3
# 11 , 6
# 11 , 42
# INSERT INTO type(type_name) VALUES ('街機');
# 11 , 102
# 11 , 95
# 11 , 14
# 11 , 36
# 11 , 1
# INSERT INTO type(type_name) VALUES ('快節奏');
# 11 , 103
# INSERT INTO type(type_name) VALUES ('遙控器');
# 11 , 104
# 11 , 47
# INSERT INTO company(company_name) VALUES ('Electronic Arts');
# Need For Speed: Hot Pursuit, TWD599, 極度好評
# https://store.steampowered.com/app/47870/Need_For_Speed_Hot_Pursuit/?snr=1_7_7_230_150_4
# ['Electronic Arts']
# ['大型多人連線', '競速', '模擬', '駕駛', '好評原聲帶', '合作', '重製', '線上合作', '擬真', '休閒', '冒險', '開放世界', '街機', '搞笑', '氛圍', '多人', '單人', '快節奏', '遙控器', '動作']
# 2010-11-16
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Life\ is\ Strange\ \-\ Episode\ 1','Episode\ 1\ now\ FREE\!\ Life\ is\ Strange\ is\ an\ award\-winning\ and\ critically\ acclaimed\ episodic\ adventure\ game\ that\ allows\ the\ player\ to\ rewind\ time\ and\ affect\ the\ past\,\ present\ and\ future\.',0,'TWD','https://store.steampowered.com/app/319630/Life_is_Strange__Episode_1/?snr=1_7_7_230_150_4','2015-1-30','壓倒性好評');
#
# 12 , 1
# 12 , 35
# 12 , 58
# 12 , 3
# 12 , 73
# 12 , 4
# 12 , 6
# 12 , 7
# 12 , 8
# INSERT INTO type(type_name) VALUES ('點擊');
# 12 , 105
# INSERT INTO type(type_name) VALUES ('時空操控');
# 12 , 106
# INSERT INTO type(type_name) VALUES ('短片');
# 12 , 107
# 12 , 14
# 12 , 15
# 12 , 16
# 12 , 17
# 12 , 47
# 12 , 18
# INSERT INTO type(type_name) VALUES ('影集');
# 12 , 108
# 12 , 38
# INSERT INTO company(company_name) VALUES ('Feral Interactive (Linux)');
# INSERT INTO company(company_name) VALUES ('Feral interactive (Mac)');
# Life is Strange - Episode 1, TWD0, 壓倒性好評
# https://store.steampowered.com/app/319630/Life_is_Strange__Episode_1/?snr=1_7_7_230_150_4
# [' Feral Interactive (Linux)', 'Square Enix', ' Feral interactive (Mac)']
# ['單人', '獨立', '步行模擬', '休閒', '女主人翁', '劇情豐富', '冒險', '時光旅行', '懸疑', '點擊', '時空操控', '短片', '氛圍', '多結局', '好評原聲帶', '網路爆紅', '動作', '選擇導向', '影集', '第三人稱視角']
# 2015-1-30
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('\江\湖\求\生\ Ganghood\ Survival','\《Ganghood\ Survival\》\ is\ a\ hardcore\ competitive\ action\ game\ based\ on\ Chinese\ Wushu\ theme\.\ Dozens\ of\ players\ are\ in\ the\ same\ map\,\ and\ play\ as\ a\ \‘Knight\-errant\’\ with\ nothing\ at\ the\ beginning\.\ They\ need\ to\ strengthen\ themselves\ by\ collecting\ resources\ and\ learning\ wushu\ books\,\ beating\ others\ to\ win\ the\ game\.',318,'TWD','https://store.steampowered.com/app/965080/_Ganghood_Survival/?snr=1_7_7_230_150_4','2018-11-12','褒貶不一');
#
# 13 , 35
# 13 , 68
# 13 , 47
# 13 , 25
# 13 , 99
# INSERT INTO company(company_name) VALUES ('雷武游戏');
# 江湖求生 Ganghood Survival, TWD318, 褒貶不一
# https://store.steampowered.com/app/965080/_Ganghood_Survival/?snr=1_7_7_230_150_4
# ['雷武游戏']
# ['獨立', '搶先體驗', '動作', '策略', '大型多人連線']
# 2018-11-12
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Deep\ Rock\ Galactic','Deep\ Rock\ Galactic\ \是\一\款\多\人\合\作\科\幻\型\第\一\人\稱\射\擊\遊\戲\，\設\有\了\不\起\的\矮\人\、100\%\ \可\破\壞\的\環\境\、\由\程\式\生\成\的\洞\穴\以\及\無\數\外\星\怪\物\群\體\。',588,'TWD','https://store.steampowered.com/app/548430/Deep_Rock_Galactic/?snr=1_7_7_230_150_4','2018-2-28','壓倒性好評');
#
# INSERT INTO type(type_name) VALUES ('程序生成');
# 14 , 109
# 14 , 1
# 14 , 68
# 14 , 78
# INSERT INTO type(type_name) VALUES ('採礦');
# 14 , 110
# 14 , 40
# 14 , 91
# 14 , 14
# 14 , 46
# 14 , 42
# 14 , 9
# 14 , 45
# 14 , 35
# 14 , 36
# 14 , 89
# 14 , 37
# 14 , 47
# 14 , 43
# 14 , 20
# INSERT INTO company(company_name) VALUES ('Coffee Stain Publishing');
# Deep Rock Galactic, TWD588, 壓倒性好評
# https://store.steampowered.com/app/548430/Deep_Rock_Galactic/?snr=1_7_7_230_150_4
# ['Coffee Stain Publishing']
# ['程序生成', '單人', '搶先體驗', '太空', '採礦', '探索', '合作', '氛圍', '生存', '開放世界', '恐怖', '射擊', '獨立', '多人', '線上合作', '第一人稱視角', '動作', '第一人稱射擊', '科幻']
# 2018-2-28
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Russian\ Fishing\ 4','Russian\ Fishing\ 4\ is\ a\ fishing\ simulator\ with\ RPG\ elements\.\ There\ is\ no\ story\ line\ and\ the\ whole\ process\ is\ based\ on\ the\ concept\ of\ an\ open\,\ free\ to\ roam\ and\ free\ to\ play\ game\.',0,'TWD','https://store.steampowered.com/app/766570/Russian_Fishing_4/?snr=1_7_7_230_150_4','2018-6-15','大多好評');
#
# 15 , 99
# 15 , 68
# 15 , 22
# 15 , 23
# INSERT INTO type(type_name) VALUES ('運動');
# 15 , 111
# 15 , 41
# 15 , 3
# 15 , 6
# 15 , 46
# 15 , 42
# 15 , 74
# 15 , 32
# 15 , 11
# 15 , 56
# 15 , 14
# 15 , 36
# 15 , 1
# 15 , 37
# INSERT INTO type(type_name) VALUES ('釣魚');
# 15 , 112
# INSERT INTO company(company_name) VALUES ('Russian Fishing');
# Russian Fishing 4, TWD0, 大多好評
# https://store.steampowered.com/app/766570/Russian_Fishing_4/?snr=1_7_7_230_150_4
# ['Russian Fishing']
# ['大型多人連線', '搶先體驗', '模擬', '擬真', '運動', '角色扮演', '休閒', '冒險', '生存', '開放世界', '裸露', '闔家', '懸疑驚悚', '免費', '氛圍', '多人', '單人', '第一人稱視角', '釣魚']
# 2018-6-15
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Half\-Life\ 2','1998\ \年\。\《\戰\慄\時\空\》\的\刺\激\動\作\與\引\人\入\勝\的\緊\湊\劇\情\，\在\遊\戲\產\業\颳\起\一\陣\旋\風\。\這\個\ Valve\ \的\處\女\作\贏\得\了\超\過\ 50\ \個\年\度\最\佳\遊\戲\獎\項\，\其\後\不\但\榮\獲\ PC\ Gamer\ \頒\予\「\史\上\最\佳\電\腦\遊\戲\」\殊\榮\，\更\發\展\成\為\全\球\零\售\銷\售\量\逾\八\百\萬\套\的\系\列\作\。\ \現\在\。\保\留\前\作\的\懸\疑\、\挑\戰\與\衝\鋒\陷\陣\的\刺\激\，\加\上\驚\心\動\魄\的\全\新\模\擬\實\境\與\人\物\對\話\，\《\戰\慄\時\空\ 2\》\帶\領\玩\家\進\入\一\個\牽\一\髮\動\全\身\的\世\界\。\無\論\是\外\在\環\境\、\行\為\，\甚\至\是\敵\友\的\情\緒\，\都\會\隨\玩\家\的\表\現\而\更\動\。\ \這\次\玩\家\再\度\拾\起\研\究\員\高\登\弗\里\曼\的\鐵\撬\，\現\身\於\被\外\星\人\佔\據\並\壓\榨\、\資\源\竭\盡\、\人\口\凋\零\的\地\球\。\弗\里\曼\被\迫\扮\演\救\世\主\的\角\色\，\從\他\自\己\在\黑\色\高\地\所\錯\放\出\的\邪\惡\手\中\拯\救\世\界\。\而\這\次\，\有\更\多\他\所\關\心\的\人\滿\心\期\待\著\他\的\成\功\。',186,'TWD','https://store.steampowered.com/app/220/HalfLife_2/?snr=1_7_7_230_150_4','2004-11-16','壓倒性好評');
#
# INSERT INTO type(type_name) VALUES ('外星人');
# 16 , 113
# 16 , 16
# INSERT INTO type(type_name) VALUES ('喪屍');
# 16 , 114
# 16 , 4
# 16 , 85
# 16 , 6
# 16 , 93
# INSERT INTO type(type_name) VALUES ('物理');
# 16 , 115
# 16 , 9
# 16 , 75
# INSERT INTO type(type_name) VALUES ('無聲主角');
# 16 , 116
# 16 , 43
# 16 , 45
# 16 , 14
# 16 , 36
# 16 , 1
# 16 , 37
# INSERT INTO type(type_name) VALUES ('反烏托邦');
# 16 , 117
# 16 , 47
# 16 , 20
# INSERT INTO company(company_name) VALUES ('Valve');
# Half-Life 2, TWD186, 壓倒性好評
# https://store.steampowered.com/app/220/HalfLife_2/?snr=1_7_7_230_150_4
# ['Valve']
# ['外星人', '好評原聲帶', '喪屍', '劇情豐富', '經典', '冒險', '傑作', '物理', '恐怖', '解謎', '無聲主角', '第一人稱射擊', '射擊', '氛圍', '多人', '單人', '第一人稱視角', '反烏托邦', '動作', '科幻']
# 2004-11-16
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Bayonetta','PlatinumGames\’\ universally\ acclaimed\ action\ masterpiece\ finally\ comes\ to\ PC\.\ Experience\ the\ over\-the\-top\ stylish\ action\ in\ 60fps\ at\ unlocked\ HD\ resolutions\.\ The\ definitive\ way\ to\ play\:\ being\ bad\ never\ felt\ so\ good\.',500,'TWD','https://store.steampowered.com/app/460790/Bayonetta/?snr=1_7_7_230_150_4','2017-4-11','極度好評');
#
# INSERT INTO type(type_name) VALUES ('血腥');
# 17 , 118
# 17 , 96
# 17 , 49
# 17 , 69
# 17 , 16
# INSERT INTO type(type_name) VALUES ('角色動作');
# 17 , 119
# 17 , 72
# 17 , 73
# 17 , 6
# 17 , 74
# INSERT INTO type(type_name) VALUES ('砍殺');
# 17 , 120
# 17 , 85
# INSERT INTO type(type_name) VALUES ('唯美格鬥');
# 17 , 121
# 17 , 12
# 17 , 14
# 17 , 1
# 17 , 103
# INSERT INTO type(type_name) VALUES ('帶狀捲軸動作');
# 17 , 122
# 17 , 47
# 17 , 38
# INSERT INTO company(company_name) VALUES ('SEGA');
# Bayonetta, TWD500, 極度好評
# https://store.steampowered.com/app/460790/Bayonetta/?snr=1_7_7_230_150_4
# ['SEGA']
# ['血腥', '歡樂', '奇幻', '色情內容', '好評原聲帶', '角色動作', '成人', '女主人翁', '冒險', '裸露', '砍殺', '經典', '唯美格鬥', '日本動畫', '氛圍', '單人', '快節奏', '帶狀捲軸動作', '動作', '第三人稱視角']
# 2017-4-11
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('theBlu','Experience\ the\ wonder\ and\ majesty\ of\ the\ ocean\ through\ a\ series\ of\ habitats\ and\ come\ face\ to\ face\ with\ some\ of\ the\ most\ awe\ inspiring\ species\ on\ the\ planet\.',278,'TWD','https://store.steampowered.com/app/451520/theBlu/?snr=1_7_7_230_150_4','2016-4-5','極度好評');
#
# 18 , 22
# 18 , 3
# 18 , 6
# 18 , 33
# 18 , 35
# 18 , 9
# INSERT INTO type(type_name) VALUES ('水底');
# 18 , 123
# INSERT INTO company(company_name) VALUES ('Inc.');
# INSERT INTO company(company_name) VALUES ('Wevr');
# theBlu, TWD278, 極度好評
# https://store.steampowered.com/app/451520/theBlu/?snr=1_7_7_230_150_4
# [' Inc.', 'Wevr']
# ['模擬', '休閒', '冒險', '虛擬實境', '獨立', '恐怖', '水底']
# 2016-4-5
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Raft','Raft\ throws\ you\ and\ your\ friends\ into\ an\ epic\ oceanic\ adventure\!\ Alone\ or\ together\,\ players\ battle\ to\ survive\ a\ perilous\ voyage\ across\ a\ vast\ sea\!\ Gather\ debris\,\ scavenge\ reefs\ and\ build\ your\ own\ floating\ home\,\ but\ be\ wary\ of\ the\ man\-eating\ sharks\!',468,'TWD','https://store.steampowered.com/app/648800/Raft/?snr=1_7_7_230_150_4','2018-5-23','極度好評');
#
# 19 , 99
# 19 , 36
# 19 , 68
# 19 , 21
# 19 , 1
# 19 , 123
# 19 , 91
# 19 , 22
# 19 , 25
# 19 , 6
# 19 , 31
# 19 , 42
# 19 , 29
# 19 , 35
# 19 , 46
# 19 , 89
# 19 , 37
# 19 , 47
# 19 , 77
# INSERT INTO company(company_name) VALUES ('Axolot Games');
# Raft, TWD468, 極度好評
# https://store.steampowered.com/app/648800/Raft/?snr=1_7_7_230_150_4
# ['Axolot Games']
# ['大型多人連線', '多人', '搶先體驗', '建造', '單人', '水底', '合作', '模擬', '策略', '冒險', '基地建設', '開放世界', '沙盒', '獨立', '生存', '線上合作', '第一人稱視角', '動作', '工藝']
# 2018-5-23
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Rust','\在\ Rust\，\唯\一\的\目\標\就\是\生\存\。\ \要\做\到\這\一\點\，\您\需\要\克\服\各\種\困\境\，\例\如\飢\餓\、\乾\渴\以\及\寒\冷\。\生\一\堆\火\。\搭\建\一\處\庇\護\所\。\獵\殺\動\物\來\做\為\食\物\。\保\護\自\己\不\受\其\他\玩\家\侵\襲\，\獵\殺\他\們\做\為\食\物\。\跟\其\他\玩\家\建\立\聯\盟\，\組\為\城\鎮\。\ \不\計\一\切\代\價\求\生\存\。',498,'TWD','https://store.steampowered.com/app/252490/Rust/?snr=1_7_7_230_150_4','2018-2-9','極度好評');
#
# 20 , 36
# 20 , 21
# 20 , 68
# 20 , 22
# INSERT INTO type(type_name) VALUES ('生存恐怖');
# 20 , 124
# 20 , 91
# INSERT INTO type(type_name) VALUES ('玩家對戰');
# 20 , 125
# 20 , 6
# 20 , 29
# 20 , 42
# 20 , 74
# 20 , 43
# 20 , 45
# 20 , 44
# 20 , 35
# 20 , 46
# 20 , 89
# 20 , 37
# 20 , 47
# 20 , 77
# INSERT INTO company(company_name) VALUES ('Facepunch Studios');
# Rust, TWD498, 極度好評
# https://store.steampowered.com/app/252490/Rust/?snr=1_7_7_230_150_4
# ['Facepunch Studios']
# ['多人', '建造', '搶先體驗', '模擬', '生存恐怖', '合作', '玩家對戰', '冒險', '沙盒', '開放世界', '裸露', '第一人稱射擊', '射擊', '末日', '獨立', '生存', '線上合作', '第一人稱視角', '動作', '工藝']
# 2018-2-9
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Slime\ Rancher','Slime\ Rancher\ is\ the\ tale\ of\ Beatrix\ LeBeau\,\ a\ plucky\,\ young\ rancher\ who\ sets\ out\ for\ a\ life\ a\ thousand\ light\ years\ away\ from\ Earth\ on\ the\ \‘Far\,\ Far\ Range\’\ where\ she\ tries\ her\ hand\ at\ making\ a\ living\ wrangling\ slimes\.',468,'TWD','https://store.steampowered.com/app/433340/Slime_Rancher/?snr=1_7_7_230_150_4','2017-8-1','壓倒性好評');
#
# 21 , 68
# 21 , 49
# 21 , 22
# 21 , 40
# 21 , 70
# 21 , 16
# 21 , 3
# 21 , 26
# 21 , 73
# 21 , 6
# 21 , 29
# 21 , 42
# INSERT INTO type(type_name) VALUES ('色彩鮮艷');
# 21 , 126
# 21 , 32
# 21 , 43
# 21 , 95
# 21 , 1
# 21 , 37
# 21 , 47
# 21 , 35
# INSERT INTO company(company_name) VALUES ('Monomi Park');
# Slime Rancher, TWD468, 壓倒性好評
# https://store.steampowered.com/app/433340/Slime_Rancher/?snr=1_7_7_230_150_4
# ['Monomi Park']
# ['搶先體驗', '奇幻', '模擬', '探索', '可愛', '好評原聲帶', '休閒', '管理', '女主人翁', '冒險', '沙盒', '開放世界', '色彩鮮艷', '闔家', '第一人稱射擊', '搞笑', '單人', '第一人稱視角', '動作', '獨立']
# 2017-8-1
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Micro\ Cosmic\ Worlds','Micro\ Cosmic\ Worlds\ is\ a\ discovery\ based\ journey\ into\ unseen\ worlds\ of\ the\ microcosmos\.\ Using\ the\ power\ of\ virtual\ reality\,\ you\ \(the\ player\)\ are\ transported\ deeper\ and\ deeper\ into\ the\ worlds\ of\ the\ infinitesimally\ small\.',258,'TWD','https://store.steampowered.com/app/655580/Micro_Cosmic_Worlds/?snr=1_7_7_230_150_4','2017-7-20',NULL);
#
# 22 , 35
# 22 , 6
# 22 , 30
# 22 , 33
# INSERT INTO company(company_name) VALUES ('Codon');
# Micro Cosmic Worlds, TWD258, NULL
# https://store.steampowered.com/app/655580/Micro_Cosmic_Worlds/?snr=1_7_7_230_150_4
# ['Codon', ' Inc.']
# ['獨立', '冒險', '教育學習', '虛擬實境']
# 2017-7-20
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Car\ Mechanic\ Simulator\ 2018','Build\ and\ expand\ your\ repair\ service\ empire\ in\ this\ incredibly\ detailed\ and\ highly\ realistic\ simulation\ game\,\ where\ attention\ to\ car\ detail\ is\ astonishing\.\ Find\ classic\,\ unique\ cars\ in\ the\ new\ Barn\ Find\ module\ and\ Junkyard\ module\.\ You\ can\ even\ add\ your\ self\-made\ car\ in\ the\ Car\ Editor\.',468,'TWD','https://store.steampowered.com/app/645630/Car_Mechanic_Simulator_2018/?snr=1_7_7_230_150_4','2017-7-28','極度好評');
#
# 23 , 99
# 23 , 21
# 23 , 100
# 23 , 22
# 23 , 23
# 23 , 83
# 23 , 16
# 23 , 25
# 23 , 26
# 23 , 79
# 23 , 91
# 23 , 30
# 23 , 29
# 23 , 42
# 23 , 115
# 23 , 17
# 23 , 36
# 23 , 1
# 23 , 37
# 23 , 77
# Car Mechanic Simulator 2018, TWD468, 極度好評
# https://store.steampowered.com/app/645630/Car_Mechanic_Simulator_2018/?snr=1_7_7_230_150_4
# ['PlayWay S.A.']
# ['大型多人連線', '建造', '競速', '模擬', '擬真', '駕駛', '好評原聲帶', '策略', '管理', '可製作模組', '合作', '教育學習', '沙盒', '開放世界', '物理', '網路爆紅', '多人', '單人', '第一人稱視角', '工藝']
# 2017-7-28
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Circle\ Empires','Circle\ Empires\ is\ a\ fresh\ take\ on\ the\ RTS\ genre\,\ featuring\ a\ fast\-paced\ approach\ to\ conquering\ the\ world\.',152,'TWD','https://store.steampowered.com/app/834740/Circle_Empires/?snr=1_7_7_230_150_4','2018-8-8','極度好評');
#
# 24 , 49
# 24 , 25
# 24 , 3
# INSERT INTO type(type_name) VALUES ('即時');
# 24 , 127
# 24 , 35
# INSERT INTO type(type_name) VALUES ('即時戰略');
# 24 , 128
# INSERT INTO company(company_name) VALUES ('Iceberg Interactive');
# Circle Empires, TWD152, 極度好評
# https://store.steampowered.com/app/834740/Circle_Empires/?snr=1_7_7_230_150_4
# ['Iceberg Interactive']
# ['奇幻', '策略', '休閒', '即時', '獨立', '即時戰略']
# 2018-8-8
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Human\:\ Fall\ Flat','Human\:\ Fall\ Flat\ is\ a\ quirky\ open\-ended\ physics\-based\ puzzle\ platformer\ set\ in\ floating\ dreamscapes\.\ Your\ goal\ is\ to\ find\ the\ exit\ of\ these\ surreal\ levels\ by\ solving\ puzzles\ with\ nothing\ but\ your\ wits\.\ Local\ co\-op\ for\ 2\ players\ and\ up\ to\ 8\ online\ for\ even\ more\ mayhem\!',398,'TWD','https://store.steampowered.com/app/477160/Human_Fall_Flat/?snr=1_7_7_230_150_4','2016-7-22','壓倒性好評');
#
# 25 , 88
# 25 , 1
# 25 , 22
# 25 , 91
# INSERT INTO type(type_name) VALUES ('分割畫面');
# 25 , 129
# 25 , 3
# 25 , 46
# 25 , 115
# 25 , 6
# 25 , 29
# 25 , 42
# INSERT INTO type(type_name) VALUES ('3D 平台');
# 25 , 130
# 25 , 75
# 25 , 63
# 25 , 95
# 25 , 36
# 25 , 96
# 25 , 97
# INSERT INTO type(type_name) VALUES ('平台解謎');
# 25 , 131
# 25 , 35
# INSERT INTO company(company_name) VALUES ('Curve Digital');
# Human: Fall Flat, TWD398, 壓倒性好評
# https://store.steampowered.com/app/477160/Human_Fall_Flat/?snr=1_7_7_230_150_4
# ['Curve Digital']
# ['單機合作', '單人', '模擬', '合作', '分割畫面', '休閒', '生存', '物理', '冒險', '沙盒', '開放世界', '3D 平台', '解謎', '跑酷', '搞笑', '多人', '歡樂', '單機多人', '平台解謎', '獨立']
# 2016-7-22
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('The\ Witcher\ 2\:\ Assassins\ of\ Kings\ Enhanced\ Edition','\兵\荒\馬\亂\的\日\子\已\然\來\臨\。\多\方\勢\力\暗\中\較\勁\，\只\為\擁\權\並\成\為\霸\主\。\北\方\諸\國\已\進\入\備\戰\狀\態\，\但\再\多\精\良\的\軍\隊\也\阻\止\不\了\一\樁\即\將\掀\起\腥\風\血\雨\的\奸\計\。',468,'TWD','https://store.steampowered.com/app/20920/The_Witcher_2_Assassins_of_Kings_Enhanced_Edition/?snr=1_7_7_230_150_5','2011-5-17','極度好評');
#
# INSERT INTO type(type_name) VALUES ('魔法');
# 26 , 132
# INSERT INTO type(type_name) VALUES ('小說改編');
# 26 , 133
# INSERT INTO type(type_name) VALUES ('黑暗');
# 26 , 134
# 26 , 49
# 26 , 72
# 26 , 41
# 26 , 4
# INSERT INTO type(type_name) VALUES ('中世纪');
# 26 , 135
# 26 , 6
# 26 , 74
# 26 , 42
# INSERT INTO type(type_name) VALUES ('黑暗奇幻');
# 26 , 136
# 26 , 94
# INSERT INTO type(type_name) VALUES ('非線性');
# 26 , 137
# 26 , 14
# 26 , 15
# 26 , 1
# 26 , 47
# 26 , 18
# 26 , 38
# INSERT INTO company(company_name) VALUES ('1C-SoftClub');
# INSERT INTO company(company_name) VALUES ('CD PROJEKT RED');
# The Witcher 2: Assassins of Kings Enhanced Edition, TWD468, 極度好評
# https://store.steampowered.com/app/20920/The_Witcher_2_Assassins_of_Kings_Enhanced_Edition/?snr=1_7_7_230_150_5
# [' 1C-SoftClub', 'CD PROJEKT RED']
# ['魔法', '小說改編', '黑暗', '奇幻', '成人', '角色扮演', '劇情豐富', '中世纪', '冒險', '裸露', '開放世界', '黑暗奇幻', '困難', '非線性', '氛圍', '多結局', '單人', '動作', '選擇導向', '第三人稱視角']
# 2011-5-17
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Plague\ Inc\:\ Evolved','\《\瘟\疫\公\司\：\進\化\》\是\一\款\結\合\了\高\度\戰\略\性\和\極\度\真\實\性\的\獨\特\模\擬\遊\戲\。\您\的\病\原\體\已\經\感\染\了\「\零\號\病\人\」\—\—\現\在\您\可\以\通\過\打\造\致\命\且\全\球\擴\散\的\病\原\體\并\使\盡\解\數\對\抗\人\類\的\反\制\手\段\，\來\抹\消\人\類\并\終\結\歷\史\。',398,'TWD','https://store.steampowered.com/app/246620/Plague_Inc_Evolved/?snr=1_7_7_230_150_5','2016-2-18','壓倒性好評');
#
# 27 , 68
# 27 , 22
# 27 , 23
# 27 , 91
# INSERT INTO type(type_name) VALUES ('戰術');
# 27 , 138
# 27 , 25
# 27 , 114
# 27 , 3
# 27 , 14
# 27 , 80
# 27 , 29
# 27 , 46
# 27 , 9
# 27 , 94
# 27 , 44
# 27 , 35
# 27 , 36
# 27 , 1
# INSERT INTO type(type_name) VALUES ('值得重玩');
# 27 , 139
# INSERT INTO type(type_name) VALUES ('易上癮');
# 27 , 140
# INSERT INTO company(company_name) VALUES ('Ndemic Creations');
# Plague Inc: Evolved, TWD398, 壓倒性好評
# https://store.steampowered.com/app/246620/Plague_Inc_Evolved/?snr=1_7_7_230_150_5
# ['Ndemic Creations']
# ['搶先體驗', '模擬', '擬真', '合作', '戰術', '策略', '喪屍', '休閒', '氛圍', '2D', '沙盒', '生存', '恐怖', '困難', '末日', '獨立', '多人', '單人', '值得重玩', '易上癮']
# 2016-2-18
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Trailmakers','\靠\直\覺\來\建\造\自\己\的\運\載\工\具\，\在\廣\大\的\開\放\式\世\界\中\暢\遊\。',468,'TWD','https://store.steampowered.com/app/585420/Trailmakers/?snr=1_7_7_230_150_5','2018-1-30','極度好評');
# 28 , 68
# 28 , 21
# 28 , 100
# 28 , 22
# 28 , 83
# 28 , 46
# INSERT INTO type(type_name) VALUES ('樂高');
# 28 , 141
# 28 , 27
# 28 , 29
# 28 , 115
# 28 , 42
# 28 , 6
# INSERT INTO type(type_name) VALUES ('飛行');
# 28 , 142
# 28 , 32
# 28 , 95
# 28 , 35
# 28 , 36
# 28 , 1
# 28 , 47
# INSERT INTO company(company_name) VALUES ('Flashbulb');
# Trailmakers, TWD468, 極度好評
# https://store.steampowered.com/app/585420/Trailmakers/?snr=1_7_7_230_150_5
# ['Flashbulb']
# ['搶先體驗', '建造', '競速', '模擬', '駕駛', '生存', '樂高', '毀滅', '沙盒', '物理', '開放世界', '冒險', '飛行', '闔家', '搞笑', '獨立', '多人', '單人', '動作']
# 2018-1-30
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Prison\ Architect','\建\造\和\管\理\一\所\高\度\設\防\的\監\獄\。',438,'TWD','https://store.steampowered.com/app/233450/Prison_Architect/?snr=1_7_7_230_150_5','2015-10-6','極度好評');
#
# 29 , 96
# 29 , 21
# 29 , 22
# 29 , 68
# INSERT INTO type(type_name) VALUES ('垂直捲軸');
# 29 , 143
# 29 , 25
# 29 , 26
# 29 , 79
# 29 , 80
# 29 , 3
# 29 , 29
# 29 , 28
# 29 , 31
# 29 , 66
# 29 , 95
# 29 , 35
# 29 , 1
# 29 , 47
# 29 , 139
# 29 , 67
# INSERT INTO company(company_name) VALUES ('Introversion Software');
# Prison Architect, TWD438, 極度好評
# https://store.steampowered.com/app/233450/Prison_Architect/?snr=1_7_7_230_150_5
# ['Introversion Software']
# ['歡樂', '建造', '模擬', '搶先體驗', '垂直捲軸', '策略', '管理', '可製作模組', '2D', '休閒', '沙盒', '經濟', '基地建設', '資源管理', '搞笑', '獨立', '單人', '動作', '值得重玩', '城市營造']
# 2015-10-6
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Liftoff\:\ FPV\ Drone\ Racing','FPV\ Drone\ Racing\ game\ Liftoff\!\ Liftoff\ is\ a\ game\ that\ translates\ the\ rush\ of\ first\-person\ view\ drone\ racing\ to\ the\ digital\ world\.\ Join\ the\ biggest\ community\ for\ virtual\ FPV\ racing\!',468,'TWD','https://store.steampowered.com/app/410340/Liftoff_FPV_Drone_Racing/?snr=1_7_7_230_150_5','2018-9-13','極度好評');
#
# 30 , 68
# 30 , 100
# 30 , 22
# 30 , 111
# 30 , 35
# 30 , 36
# INSERT INTO company(company_name) VALUES ('LuGus Studios');
# Liftoff: FPV Drone Racing, TWD468, 極度好評
# https://store.steampowered.com/app/410340/Liftoff_FPV_Drone_Racing/?snr=1_7_7_230_150_5
# ['LuGus Studios']
# ['搶先體驗', '競速', '模擬', '運動', '獨立', '多人']
# 2018-9-13
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('rFactor\ 2','rFactor\ 2\ is\ a\ realistic\,\ easily\ extendable\ racing\ simulation\ that\ offers\ the\ latest\ in\ vehicle\ and\ race\ customization\,\ great\ graphics\,\ outstanding\ multiplayer\ and\ the\ height\ of\ racing\ realism\.\ It\ features\ mixed\ class\ road\ racing\ with\ ultra\ realistic\ dynamics\,\ an\ immersive\ sound\ environment\ and\ stunning\ graphics\.',468,'TWD','https://store.steampowered.com/app/365960/rFactor_2/?snr=1_7_7_230_150_5','2013-3-28','極度好評');
#
# 31 , 100
# 31 , 23
# 31 , 83
# 31 , 22
# 31 , 111
# 31 , 36
# 31 , 1
# INSERT INTO company(company_name) VALUES ('Studio 397');
# rFactor 2, TWD468, 極度好評
# https://store.steampowered.com/app/365960/rFactor_2/?snr=1_7_7_230_150_5
# ['Studio 397']
# ['競速', '擬真', '駕駛', '模擬', '運動', '多人', '單人']
# 2013-3-28
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Age\ of\ Empires\®\ III\:\ Complete\ Collection','Microsoft\ Studios\ brings\ you\ three\ epic\ Age\ of\ Empires\ III\ games\ in\ one\ monumental\ collection\ for\ the\ first\ time\.',868,'TWD','https://store.steampowered.com/app/105450/Age_of_Empires_III_Complete_Collection/?snr=1_7_7_230_150_5','2009-9-15','極度好評');
#
# INSERT INTO type(type_name) VALUES ('戰爭');
# 32 , 144
# 32 , 21
# 32 , 22
# 32 , 89
# 32 , 91
# 32 , 25
# INSERT INTO type(type_name) VALUES ('即時含暫停');
# 32 , 145
# 32 , 85
# 32 , 31
# 32 , 42
# 32 , 6
# 32 , 61
# 32 , 66
# 32 , 127
# 32 , 36
# 32 , 1
# INSERT INTO type(type_name) VALUES ('軍事');
# 32 , 146
# 32 , 47
# 32 , 128
# 32 , 67
# INSERT INTO company(company_name) VALUES ('Microsoft Studios');
# Age of Empires® III: Complete Collection, TWD868, 極度好評
# https://store.steampowered.com/app/105450/Age_of_Empires_III_Complete_Collection/?snr=1_7_7_230_150_5
# ['Microsoft Studios']
# ['戰爭', '建造', '模擬', '線上合作', '合作', '策略', '即時含暫停', '經典', '基地建設', '開放世界', '冒險', '歷史', '資源管理', '即時', '多人', '單人', '軍事', '動作', '即時戰略', '城市營造']
# 2009-9-15
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Factorio','Factorio\ is\ a\ game\ about\ building\ and\ creating\ automated\ factories\ to\ produce\ items\ of\ increasing\ complexity\,\ within\ an\ infinite\ 2D\ world\.\ Use\ your\ imagination\ to\ design\ your\ factory\,\ combine\ simple\ elements\ into\ ingenious\ structures\,\ and\ finally\ protect\ it\ from\ the\ creatures\ who\ don\'t\ really\ like\ you\.',430,'TWD','https://store.steampowered.com/app/427520/Factorio/?snr=1_7_7_230_150_5','2016-2-25','壓倒性好評');
#
# 33 , 36
# 33 , 68
# 33 , 22
# 33 , 20
# 33 , 113
# 33 , 91
# INSERT INTO type(type_name) VALUES ('塔防');
# 33 , 147
# 33 , 25
# 33 , 26
# 33 , 79
# 33 , 31
# 33 , 29
# 33 , 42
# 33 , 66
# INSERT INTO type(type_name) VALUES ('火車');
# 33 , 148
# 33 , 35
# 33 , 46
# 33 , 1
# 33 , 77
# INSERT INTO company(company_name) VALUES ('Wube Software LTD.');
# Factorio, TWD430, 壓倒性好評
# https://store.steampowered.com/app/427520/Factorio/?snr=1_7_7_230_150_5
# ['Wube Software LTD.']
# ['多人', '搶先體驗', '模擬', '科幻', '外星人', '合作', '塔防', '策略', '管理', '可製作模組', '基地建設', '沙盒', '開放世界', '資源管理', '火車', '獨立', '生存', '單人', '工藝']
# 2016-2-25
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Wolcen\:\ Lords\ of\ Mayhem','A\ dynamic\ hack\’n\’slash\ with\ no\ class\ restrictions\.\ Choose\ your\ path\ as\ you\ level\-up\ and\ play\ your\ character\ the\ way\ you\ want\!\ Explore\ this\ shattered\ and\ corrupted\ world\ to\ uncover\ its\ ancient\ secrets\ and\ hidden\ truths\.',468,'TWD','https://store.steampowered.com/app/424370/Wolcen_Lords_of_Mayhem/?snr=1_7_7_230_150_5','2016-3-24','大多好評');
#
# 34 , 68
# 34 , 49
# 34 , 41
# 34 , 135
# 34 , 6
# 34 , 74
# 34 , 120
# 34 , 42
# INSERT INTO type(type_name) VALUES ('尋寶');
# 34 , 149
# 34 , 53
# 34 , 54
# 34 , 35
# 34 , 36
# 34 , 1
# 34 , 47
# 34 , 48
# INSERT INTO type(type_name) VALUES ('等角');
# 34 , 150
# INSERT INTO company(company_name) VALUES ('WOLCEN Studio');
# Wolcen: Lords of Mayhem, TWD468, 大多好評
# https://store.steampowered.com/app/424370/Wolcen_Lords_of_Mayhem/?snr=1_7_7_230_150_5
# ['WOLCEN Studio']
# ['搶先體驗', '奇幻', '角色扮演', '中世纪', '冒險', '裸露', '砍殺', '開放世界', '尋寶', '自創角色', 'MMORPG', '獨立', '多人', '單人', '動作', '動作角色扮演', '等角']
# 2016-3-24
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Men\ of\ War\:\ Assault\ Squad\ 2','Men\ of\ War\:\ Assault\ Squad\ 2\ features\ new\ single\ player\ style\ skirmish\ modes\ that\ take\ players\ from\ extreme\ tank\ combat\ to\ deadly\ sniper\ stealth\ missions\.\ Commanders\ can\ now\ faceoff\ against\ opponents\ on\ various\ new\ multiplayer\ 1v1\ \–\ 8v8\ maps\.',438,'TWD','https://store.steampowered.com/app/244450/Men_of_War_Assault_Squad_2/?snr=1_7_7_230_150_5','2014-5-15','極度好評');
#
# 35 , 144
# INSERT INTO type(type_name) VALUES ('即時戰術');
# 35 , 151
# INSERT INTO type(type_name) VALUES ('坦克');
# 35 , 152
# 35 , 22
# 35 , 23
# 35 , 91
# 35 , 25
# INSERT INTO type(type_name) VALUES ('二戰');
# 35 , 153
# 35 , 14
# 35 , 27
# 35 , 85
# 35 , 6
# 35 , 61
# 35 , 94
# 35 , 138
# 35 , 36
# 35 , 1
# 35 , 146
# 35 , 47
# 35 , 128
# INSERT INTO company(company_name) VALUES ('1C Entertainment');
# Men of War: Assault Squad 2, TWD438, 極度好評
# https://store.steampowered.com/app/244450/Men_of_War_Assault_Squad_2/?snr=1_7_7_230_150_5
# ['1C Entertainment']
# ['戰爭', '即時戰術', '坦克', '模擬', '擬真', '合作', '策略', '二戰', '氛圍', '毀滅', '經典', '冒險', '歷史', '困難', '戰術', '多人', '單人', '軍事', '動作', '即時戰略']
# 2014-5-15
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Sniper\ Elite\ 4','\在\史\上\最\大\也\最\先\進\的\第\二\次\世\界\大\戰\射\擊\遊\戲\中\，\盡\享\無\與\倫\比\的\自\由\狙\擊\。\在\波\瀾\壯\闊\的\關\卡\中\體\驗\戰\術\級\別\的\第\三\人\稱\戰\鬥\、\遊\戲\方\式\選\擇\，\以\及\史\詩\般\的\長\距\離\射\擊\，\從\法\西\斯\主\義\的\魔\掌\中\讓\戰\爭\時\期\的\義\大\利\得\到\解\放\。',1248,'TWD','https://store.steampowered.com/app/312660/Sniper_Elite_4/?snr=1_7_7_230_150_5','2017-2-13','極度好評');
#
# 36 , 144
# 36 , 118
# 36 , 39
# 36 , 64
# 36 , 91
# 36 , 153
# 36 , 25
# 36 , 14
# 36 , 6
# 36 , 74
# 36 , 42
# INSERT INTO type(type_name) VALUES ('狙擊手');
# 36 , 154
# 36 , 43
# 36 , 45
# 36 , 62
# 36 , 138
# 36 , 36
# 36 , 1
# 36 , 47
# 36 , 38
# INSERT INTO company(company_name) VALUES ('Rebellion');
# Sniper Elite 4, TWD1248, 極度好評
# https://store.steampowered.com/app/312660/Sniper_Elite_4/?snr=1_7_7_230_150_5
# ['Rebellion']
# ['戰爭', '血腥', '第三人稱射擊', '暴力', '合作', '二戰', '策略', '氛圍', '冒險', '裸露', '開放世界', '狙擊手', '第一人稱射擊', '射擊', '潛行', '戰術', '多人', '單人', '動作', '第三人稱視角']
# 2017-2-13
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Ultimate\ Chicken\ Horse','Ultimate\ Chicken\ Horse\ \是\一\款\由\玩\家\自\行\創\作\關\卡\的\互\動\遊\戲\，\在\想\方\設\法\妨\礙\對\手\到\達\終\點\的\同\時\，\也\不\要\栽\在\自\己\設\下\的\陷\阱\和\障\礙\面\前\。',268,'TWD','https://store.steampowered.com/app/386940/Ultimate_Chicken_Horse/?snr=1_7_7_230_150_5','2016-3-4','壓倒性好評');
#
# 37 , 1
# 37 , 90
# 37 , 70
# INSERT INTO type(type_name) VALUES ('四人單機');
# 37 , 155
# INSERT INTO type(type_name) VALUES ('競技');
# 37 , 156
# 37 , 3
# 37 , 25
# 37 , 80
# 37 , 6
# 37 , 75
# 37 , 104
# 37 , 94
# 37 , 63
# 37 , 95
# 37 , 36
# 37 , 16
# 37 , 97
# 37 , 47
# 37 , 98
# 37 , 35
# INSERT INTO company(company_name) VALUES ('Clever Endeavour Games');
# Ultimate Chicken Horse, TWD268, 壓倒性好評
# https://store.steampowered.com/app/386940/Ultimate_Chicken_Horse/?snr=1_7_7_230_150_5
# ['Clever Endeavour Games']
# ['單人', '關卡編輯', '可愛', '四人單機', '競技', '休閒', '策略', '2D', '冒險', '解謎', '遙控器', '困難', '跑酷', '搞笑', '多人', '好評原聲帶', '單機多人', '動作', '平台', '獨立']
# 2016-3-4
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Subnautica','Descend\ into\ the\ depths\ of\ an\ alien\ underwater\ world\ filled\ with\ wonder\ and\ peril\.\ Craft\ equipment\,\ pilot\ submarines\ and\ out\-smart\ wildlife\ to\ explore\ lush\ coral\ reefs\,\ volcanoes\,\ cave\ systems\,\ and\ more\ \-\ all\ while\ trying\ to\ survive\.',378,'TWD','https://store.steampowered.com/app/264710/Subnautica/?snr=1_7_7_230_150_5','2018-1-23','壓倒性好評');
#
# 38 , 20
# 38 , 113
# 38 , 68
# 38 , 77
# 38 , 40
# 38 , 124
# 38 , 6
# 38 , 31
# 38 , 42
# 38 , 29
# 38 , 33
# 38 , 43
# 38 , 14
# 38 , 46
# 38 , 1
# 38 , 37
# 38 , 47
# 38 , 9
# 38 , 35
# 38 , 123
# INSERT INTO company(company_name) VALUES ('Unknown Worlds Entertainment');
# Subnautica, TWD378, 壓倒性好評
# https://store.steampowered.com/app/264710/Subnautica/?snr=1_7_7_230_150_5
# ['Unknown Worlds Entertainment']
# ['科幻', '外星人', '搶先體驗', '工藝', '探索', '生存恐怖', '冒險', '基地建設', '開放世界', '沙盒', '虛擬實境', '第一人稱射擊', '氛圍', '生存', '單人', '第一人稱視角', '動作', '恐怖', '獨立', '水底']
# 2018-1-23
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Trove','Discover\ a\ new\ world\ filled\ with\ danger\ and\ adventure\ in\ Trove\ \–\ Geode\.\ Use\ special\ abilities\ to\ explore\ mysterious\ caverns\,\ make\ friends\ with\ new\ races\ and\ new\ creatures\,\ or\ just\ have\ a\ blast\ as\ you\ fight\ to\ be\ the\ last\ Trovian\ standing\ in\ the\ explosive\ new\ Bomber\ Royale\ mode\.',0,'TWD','https://store.steampowered.com/app/304050/Trove/?snr=1_7_7_230_150_5','2015-7-9','極度好評');
#
# 39 , 99
# 39 , 38
# 39 , 21
# 39 , 40
# 39 , 91
# 39 , 41
# 39 , 3
# 39 , 6
# 39 , 29
# 39 , 42
# INSERT INTO type(type_name) VALUES ('立體像素');
# 39 , 157
# 39 , 54
# 39 , 81
# 39 , 43
# INSERT INTO type(type_name) VALUES ('迷宮探索');
# 39 , 158
# 39 , 56
# 39 , 95
# 39 , 36
# 39 , 47
# 39 , 77
# INSERT INTO company(company_name) VALUES ('Trion Worlds');
# Trove, TWD0, 極度好評
# https://store.steampowered.com/app/304050/Trove/?snr=1_7_7_230_150_5
# ['Trion Worlds']
# ['大型多人連線', '第三人稱視角', '建造', '探索', '合作', '角色扮演', '休閒', '冒險', '沙盒', '開放世界', '立體像素', 'MMORPG', '像素風格', '第一人稱射擊', '迷宮探索', '免費', '搞笑', '多人', '動作', '工藝']
# 2015-7-9
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Shining\ Resonance\ Refrain','\扮\演\悠\瑪\・\易\爾\本\，\阻\止\帝\國\濫\用\古\龍\的\力\量\，\包\括\依\宿\在\你\體\內\「\煌\龍\」\的\魂\魄\。\在\朋\友\的\幫\助\下\實\現\你\的\命\運\，\拯\救\阿\斯\托\利\亞\王\國\，\釋\放\你\長\久\以\來\封\印\的\力\量\。',1390,'TWD','https://store.steampowered.com/app/809890/Shining_Resonance_Refrain/?snr=1_7_7_230_150_5','2018-7-9','大多好評');
#
# INSERT INTO type(type_name) VALUES ('龍');
# 40 , 159
# 40 , 69
# 40 , 52
# 40 , 41
# 40 , 73
# 40 , 4
# 40 , 6
# 40 , 74
# 40 , 120
# 40 , 12
# 40 , 1
# 40 , 47
# 40 , 48
# Shining Resonance Refrain, TWD1390, 大多好評
# https://store.steampowered.com/app/809890/Shining_Resonance_Refrain/?snr=1_7_7_230_150_5
# ['SEGA']
# ['龍', '色情內容', '日系角色扮演', '角色扮演', '女主人翁', '劇情豐富', '冒險', '裸露', '砍殺', '日本動畫', '單人', '動作', '動作角色扮演']
# 2018-7-9
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('\東\方\憑\依\華\　\～\ Antinomy\ of\ Common\ Flowers\.','\今\度\の\異\変\は\二\人\で\一\人\？\ \い\ま\だ\煽\り\続\け\る\都\市\伝\説\が\新\た\な\異\変\を\引\き\起\こ\す\ \今\度\の\異\変\は\二\人\が\一\人\！\？\な\ら\ば\二\人\で\解\決\す\る\し\か\な\い\！',378,'TWD','https://store.steampowered.com/app/716710/_Antinomy_of_Common_Flowers/?snr=1_7_7_230_150_5','2018-1-5','極度好評');
#
# 41 , 1
# 41 , 49
# 41 , 70
# INSERT INTO type(type_name) VALUES ('信仰');
# 41 , 160
# 41 , 73
# INSERT INTO type(type_name) VALUES ('故事架構豐富');
# 41 , 161
# 41 , 80
# 41 , 4
# INSERT INTO type(type_name) VALUES ('彈幕');
# 41 , 162
# 41 , 102
# 41 , 32
# 41 , 11
# INSERT INTO type(type_name) VALUES ('格鬥');
# 41 , 163
# 41 , 12
# INSERT INTO type(type_name) VALUES ('2D 格鬥');
# 41 , 164
# 41 , 94
# 41 , 35
# 41 , 36
# 41 , 16
# 41 , 47
# INSERT INTO company(company_name) VALUES ('SUNFISH Co.');
# 東方憑依華　～ Antinomy of Common Flowers., TWD378, 極度好評
# https://store.steampowered.com/app/716710/_Antinomy_of_Common_Flowers/?snr=1_7_7_230_150_5
# ['SUNFISH Co.', ' Ltd.']
# ['單人', '奇幻', '可愛', '信仰', '女主人翁', '故事架構豐富', '2D', '劇情豐富', '彈幕', '街機', '闔家', '懸疑驚悚', '格鬥', '日本動畫', '2D 格鬥', '困難', '獨立', '多人', '好評原聲帶', '動作']
# 2018-1-5
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Terraria','Dig\,\ fight\,\ explore\,\ build\!\ Nothing\ is\ impossible\ in\ this\ action\-packed\ adventure\ game\.\ Four\ Pack\ also\ available\!',278,'TWD','https://store.steampowered.com/app/105600/Terraria/?snr=1_7_7_230_150_5','2011-5-16','壓倒性好評');
#
# 42 , 36
# 42 , 21
# 42 , 1
# 42 , 98
# 42 , 40
# 42 , 91
# 42 , 14
# 42 , 41
# 42 , 80
# 42 , 6
# 42 , 29
# 42 , 42
# 42 , 32
# 42 , 81
# 42 , 139
# 42 , 35
# 42 , 46
# 42 , 89
# 42 , 47
# 42 , 77
# INSERT INTO company(company_name) VALUES ('Re-Logic');
# Terraria, TWD278, 壓倒性好評
# https://store.steampowered.com/app/105600/Terraria/?snr=1_7_7_230_150_5
# ['Re-Logic']
# ['多人', '建造', '單人', '平台', '探索', '合作', '氛圍', '角色扮演', '2D', '冒險', '沙盒', '開放世界', '闔家', '像素風格', '值得重玩', '獨立', '生存', '線上合作', '動作', '工藝']
# 2011-5-16
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Project\ Hospital','Become\ an\ ace\ doctor\,\ an\ aspiring\ architect\ and\ a\ successful\ manager\ at\ the\ same\ time\.\ Design\ your\ very\ own\ hospital\,\ tweak\ every\ detail\ or\ use\ one\ of\ the\ predefined\ models\ and\ just\ jump\ to\ the\ doctor\’s\ duty\.',378,'TWD','https://store.steampowered.com/app/868360/Project_Hospital/?snr=1_7_7_230_150_5','2018-10-30','極度好評');
#
# 43 , 21
# 43 , 22
# 43 , 25
# 43 , 26
# 43 , 35
# 43 , 1
# INSERT INTO company(company_name) VALUES ('Oxymoron Games');
# Project Hospital, TWD378, 極度好評
# https://store.steampowered.com/app/868360/Project_Hospital/?snr=1_7_7_230_150_5
# ['Oxymoron Games']
# ['建造', '模擬', '策略', '管理', '獨立', '單人']
# 2018-10-30
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Shift\ Happens','Shift\ Happens\ is\ a\ cooperative\ platformer\ for\ two\.\ You\ and\ a\ friend\ shift\ your\ mass\,\ throw\ each\ other\ and\ puzzle\ your\ way\ through\ four\ stages\ of\ stylized\ imaginary\ worlds\.\ Including\ the\ occasional\ backstabbing\ and\ taunting\.\ Play\ with\ a\ friend\ on\ a\ couch\,\ online\ or\ even\ special\ singleplayer\ levels\.',398,'TWD','https://store.steampowered.com/app/359840/Shift_Happens/?snr=1_7_7_230_150_5','2017-2-22','極度好評');
#
# 44 , 88
# 44 , 36
# INSERT INTO type(type_name) VALUES ('假3D');
# 44 , 165
# 44 , 68
# 44 , 98
# 44 , 91
# 44 , 16
# 44 , 75
# 44 , 35
# 44 , 97
# 44 , 89
# 44 , 104
# 44 , 131
# 44 , 47
# INSERT INTO company(company_name) VALUES ('Deck13');
# INSERT INTO company(company_name) VALUES ('FFF Bayern');
# INSERT INTO company(company_name) VALUES ('Klonk Games');
# Shift Happens, TWD398, 極度好評
# https://store.steampowered.com/app/359840/Shift_Happens/?snr=1_7_7_230_150_5
# [' Deck13', ' FFF Bayern', 'Klonk Games']
# ['單機合作', '多人', '假3D', '搶先體驗', '平台', '合作', '好評原聲帶', '解謎', '獨立', '單機多人', '線上合作', '遙控器', '平台解謎', '動作']
# 2017-2-22
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Warhammer\:\ Vermintide\ 2','\本\作\是\廣\受\好\評\的\遊\戲\《Vermintide\》\的\續\作\。\這\款\遊\戲\將\以\震\撼\的\視\覺\效\果\和\開\創\性\的\近\戰\動\作\遊\戲\方\式\，\將\第\一\人\稱\視\角\合\作\遊\戲\推\向\新\的\高\度\。',438,'TWD','https://store.steampowered.com/app/552500/Warhammer_Vermintide_2/?snr=1_7_7_230_150_5','2018-3-8','極度好評');
#
# 45 , 118
# 45 , 1
# 45 , 64
# 45 , 49
# 45 , 91
# 45 , 35
# 45 , 46
# 45 , 6
# 45 , 120
# 45 , 42
# INSERT INTO type(type_name) VALUES ('玩家合作');
# 45 , 166
# 45 , 43
# INSERT INTO type(type_name) VALUES ('遊戲工坊');
# 45 , 167
# 45 , 14
# 45 , 36
# 45 , 89
# 45 , 37
# 45 , 47
# 45 , 48
# 45 , 136
# INSERT INTO company(company_name) VALUES ('Fatshark');
# Warhammer: Vermintide 2, TWD438, 極度好評
# https://store.steampowered.com/app/552500/Warhammer_Vermintide_2/?snr=1_7_7_230_150_5
# ['Fatshark']
# ['血腥', '單人', '暴力', '奇幻', '合作', '獨立', '生存', '冒險', '砍殺', '開放世界', '玩家合作', '第一人稱射擊', '遊戲工坊', '氛圍', '多人', '線上合作', '第一人稱視角', '動作', '動作角色扮演', '黑暗奇幻']
# 2018-3-8
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('XCOM\®\ 2','XCOM\ 2\是\獲\得\最\傑\出\遊\戲\獎\的\策\略\遊\戲XCOM\:\ Enemy\ Unknown\的\續\作\。\自\從\人\類\敗\給\外\星\入\侵\者\之\後\已\經\過\了20\年\，\地\球\上\已\經\建\立\起\了\新\的\秩\序\。\在\暗\處\中\蟄\伏\多\年\的XCOM\殘\存\勢\力\必\須\崛\起\并\將\外\星\人\驅\逐\出\地\球\。',1790,'TWD','https://store.steampowered.com/app/268500/XCOM_2/?snr=1_7_7_230_150_5','2016-2-4','極度好評');
#
# 46 , 113
# 46 , 16
# 46 , 51
# 46 , 25
# 46 , 14
# 46 , 79
# 46 , 41
# 46 , 91
# INSERT INTO type(type_name) VALUES ('回合制戰術');
# 46 , 168
# 46 , 53
# INSERT INTO type(type_name) VALUES ('永久死亡');
# 46 , 169
# 46 , 42
# INSERT INTO type(type_name) VALUES ('未來');
# 46 , 170
# 46 , 94
# 46 , 138
# 46 , 36
# 46 , 1
# INSERT INTO type(type_name) VALUES ('回合制策略');
# 46 , 171
# 46 , 47
# 46 , 20
# XCOM® 2, TWD1790, 極度好評
# https://store.steampowered.com/app/268500/XCOM_2/?snr=1_7_7_230_150_5
# [' Feral Interactive (Linux)', ' Feral Interactive (Mac)', '2K']
# ['外星人', '好評原聲帶', '回合制', '策略', '氛圍', '可製作模組', '角色扮演', '合作', '回合制戰術', '自創角色', '永久死亡', '開放世界', '未來', '困難', '戰術', '多人', '單人', '回合制策略', '動作', '科幻']
# 2016-2-4
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Castle\ Crashers\®','\在\ The\ Behemoth\ \這\款\得\獎\作\品\中\依\您\的\方\式\殺\出\血\路\並\贏\得\勝\利\吧\！',268,'TWD','https://store.steampowered.com/app/204360/Castle_Crashers/?snr=1_7_7_230_150_5','2012-9-26','壓倒性好評');
#
# 47 , 88
# 47 , 96
# 47 , 49
# 47 , 91
# 47 , 16
# INSERT INTO type(type_name) VALUES ('橫向捲軸');
# 47 , 172
# 47 , 41
# 47 , 3
# 47 , 80
# 47 , 6
# 47 , 120
# 47 , 104
# 47 , 95
# 47 , 35
# 47 , 36
# 47 , 89
# 47 , 97
# 47 , 122
# 47 , 47
# 47 , 48
# Castle Crashers®, TWD268, 壓倒性好評
# https://store.steampowered.com/app/204360/Castle_Crashers/?snr=1_7_7_230_150_5
# ['The Behemoth']
# ['單機合作', '歡樂', '奇幻', '合作', '好評原聲帶', '橫向捲軸', '角色扮演', '休閒', '2D', '冒險', '砍殺', '遙控器', '搞笑', '獨立', '多人', '線上合作', '單機多人', '帶狀捲軸動作', '動作', '動作角色扮演']
# 2012-9-26
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Black\ Squad','Black\ Squad\ is\ a\ military\ first\-person\-shooter\ game\ using\ the\ Unreal\ Engine\ 3\ to\ show\ realistic\ graphics\ and\ dynamic\ visuals\.\ Absolutely\ no\ Pay\-to\-Win\.\ Welcome\ to\ the\ best\ F2P\ shooter\ on\ the\ market\.\ Easy\ to\ adapt\ and\ a\ shooting\ game\ oriented\ for\ mass\ military\ lovers\.',0,'TWD','https://store.steampowered.com/app/550650/Black_Squad/?snr=1_7_7_230_150_5','2017-7-28','極度好評');
#
# 48 , 99
# 48 , 144
# 48 , 68
# 48 , 64
# 48 , 118
# 48 , 91
# 48 , 92
# 48 , 25
# 48 , 125
# 48 , 42
# 48 , 43
# 48 , 45
# 48 , 56
# 48 , 138
# 48 , 36
# 48 , 1
# 48 , 37
# 48 , 146
# 48 , 47
# INSERT INTO company(company_name) VALUES ('NS STUDIO');
# INSERT INTO company(company_name) VALUES ('NEOBRICKS');
# Black Squad, TWD0, 極度好評
# https://store.steampowered.com/app/550650/Black_Squad/?snr=1_7_7_230_150_5
# ['NS STUDIO', ' NEOBRICKS']
# ['大型多人連線', '戰爭', '搶先體驗', '暴力', '血腥', '合作', '團隊導向', '策略', '玩家對戰', '開放世界', '第一人稱射擊', '射擊', '免費', '戰術', '多人', '單人', '第一人稱視角', '軍事', '動作']
# 2017-7-28
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('Meltys\ Quest','Princess\ Meltys\ spent\ all\ her\ life\ fooling\ around\ while\ living\ in\ the\ lap\ of\ luxury\.\ One\ day\ the\ dastardly\ Grolido\ Monster\ Empire\ upsets\ her\ way\ of\ life\.\ Now\ she\ sets\ out\ on\ a\ passionate\ journey\ to\ restore\ her\ kingdom\,\ but\ what\ pit\ stops\ will\ she\ make\ along\ the\ way\?',318,'TWD','https://store.steampowered.com/app/723090/Meltys_Quest/?snr=1_7_7_230_150_5','2017-10-24','極度好評');
#
# 49 , 69
# 49 , 72
# 49 , 52
# 49 , 41
# 49 , 73
# 49 , 74
# 49 , 76
# 49 , 12
# 49 , 95
# 49 , 35
# 49 , 15
# 49 , 17
# INSERT INTO type(type_name) VALUES ('RPG製作大師');
# 49 , 173
# INSERT INTO company(company_name) VALUES ('Remtairy');
# Meltys Quest, TWD318, 極度好評
# https://store.steampowered.com/app/723090/Meltys_Quest/?snr=1_7_7_230_150_5
# ['Remtairy']
# ['色情內容', '成人', '日系角色扮演', '角色扮演', '女主人翁', '裸露', '工作場所不宜', '日本動畫', '搞笑', '獨立', '多結局', '網路爆紅', 'RPG製作大師']
# 2017-10-24
#
# INSERT INTO game(game_name,game_introduction,game_price,game_price_currency,game_store_URL,game_release_date,game_score) VALUES ('VR\ SUPER\ SPORTS','\痴\迷\於\體\育\運\動\麼\？\那\完\全\不\需\要\擔\心\。\這\個\非\常\容\易\操\作\，\即\便\是\你\沒\有\足\夠\ \的\技\巧\或\者\專\業\的\知\識\。\你\可\以\用\操\作\桿\和\你\的\身\體\來\體\驗\一\個\現\實\的\，\一\個\全\ \新\的\體\育\運\動\。',358,'TWD','https://store.steampowered.com/app/593240/VR_SUPER_SPORTS/?snr=1_7_7_230_150_5','2017-3-13','大多好評');
#
# 50 , 22
# INSERT INTO type(type_name) VALUES ('籃球');
# 50 , 174
# 50 , 100
# 50 , 111
# 50 , 3
# INSERT INTO type(type_name) VALUES ('保齡球');
# 50 , 175
# 50 , 33
# 50 , 35
# 50 , 47
# INSERT INTO company(company_name) VALUES ('SAT-BOX');
# VR SUPER SPORTS, TWD358, 大多好評
# https://store.steampowered.com/app/593240/VR_SUPER_SPORTS/?snr=1_7_7_230_150_5
# ['SAT-BOX']
# ['模擬', '籃球', '競速', '運動', '休閒', '保齡球', '虛擬實境', '獨立', '動作']
# 2017-3-13
#
# {'等角': 150, '懸疑驚悚': 11, '生存恐怖': 124, '經濟': 28, '懸疑': 8, '沙盒': 29, '尋寶': 149, '資源管理': 66, '2D 格鬥': 164, '軍事': 146, '值得重玩': 139, '程序生成': 109, '塔防': 147, '信仰': 160, '砍殺': 120, 'RPG製作大師': 173, '快節奏': 103, '第一人稱射擊': 43, '恐龍': 65, '團隊導向': 92, '女主人翁': 73, '教育學習': 30, '色彩鮮艷': 126, '歷史': 61, '驚悚': 2, '唯美格鬥': 121, '網路爆紅': 17, '第一人稱視角': 37, '平台': 98, '競速': 100, '步行模擬': 58, '可愛': 70, '反烏托邦': 117, '戀愛模擬': 5, '毀滅': 27, '角色扮演': 41, '多人': 36, '好評原聲帶': 16, '第三人稱視角': 38, '暴力': 64, '單機合作': 88, '搶先體驗': 68, '喪屍': 114, '物理': 115, '保齡球': 175, '自創角色': 53, '彈幕': 162, '奇幻': 49, '日本動畫': 12, '氛圍': 14, '龍': 159, '垂直捲軸': 143, '競技': 156, '劇情豐富': 4, '光明會': 59, '虛擬實境': 33, '開放世界': 42, '像素風格': 81, '獨立': 35, '黑暗奇幻': 136, '回合制策略': 171, '影集': 108, '科幻': 20, '血腥': 118, '即時戰術': 151, '關卡編輯': 90, '日系角色扮演': 52, '樂高': 141, '解謎': 75, '卡牌': 55, '重製': 101, '火車': 148, '免費': 56, '擬真': 23, '選擇導向': 18, '美國': 82, '第三人稱射擊': 39, '模擬': 22, '駕駛': 83, '角色動作': 119, '策略': 25, '裸露': 74, '暗殺': 60, '永久死亡': 169, '未來': 170, '玩家合作': 166, '非線性': 137, '潛行': 62, '設計及繪圖': 34, '線上合作': 89, '帶狀捲軸動作': 122, '三消': 71, '太空': 78, '外星人': 113, '採礦': 110, '探索': 40, '二戰': 153, '2D': 80, '飛行': 142, '基地建設': 31, '多結局': 15, '單人': 1, '視覺小說': 19, '工藝': 77, '戰爭': 144, '色情內容': 69, '放鬆': 24, '3D 平台': 130, '回合制戰術': 168, '水底': 123, '假3D': 165, '籃球': 174, '運動': 111, '即時含暫停': 145, '科學': 13, '無聲主角': 116, '動作': 47, '黑暗': 134, '橫向捲軸': 172, '休閒': 3, '中世纪': 135, '闔家': 32, '末日': 44, '街機': 102, '即時': 127, '困難': 94, '生存': 46, '易上癮': 140, '遙控器': 104, '坦克': 152, '小說改編': 133, '成人': 72, '3D 視覺': 84, '傑作': 93, '建造': 21, 'MMORPG': 54, '工作場所不宜': 76, '搞笑': 95, '釣魚': 112, '音樂': 87, '大型多人連線': 99, '回合制戰鬥': 50, '回合制': 51, '管理': 26, '故事架構豐富': 161, '分割畫面': 129, '狙擊手': 154, '點擊': 105, '單機多人': 97, '魔法': 132, '恐怖': 9, '動作角色扮演': 48, '城市營造': 67, '玩家對戰': 125, '經典': 85, '可製作模組': 79, '冒險': 6, '立體像素': 157, '時光旅行': 7, '格鬥': 163, '跑酷': 63, '戰術': 138, '歡樂': 96, '平台解謎': 131, '搶劫': 57, '合作': 91, '射擊': 45, '愛情': 10, '迷宮探索': 158, '遊戲工坊': 167, '時空操控': 106, '短片': 107, '四人單機': 155, '犯罪': 86, '即時戰略': 128}
# {'Re-Logic': 46, 'Ludeon Studios': 10, 'Russian Fishing': 19, 'Electronic Arts': 14, 'PlayWay S.A.': 4, '1C Entertainment': 40, 'CD PROJEKT RED': 31, 'Frontier Developments': 8, '2K': 12, 'Feral Interactive (Mac)': 11, 'Bethesda Softworks': 5, 'Wube Software LTD.': 38, 'Flashbulb': 33, 'Facepunch Studios': 25, 'Inc.': 22, 'Feral Interactive (Linux)': 15, 'Microsoft Studios': 37, 'SAT-BOX': 55, 'Iceberg Interactive': 28, 'Coffee Stain Publishing': 18, 'Remtairy': 54, 'Oxymoron Games': 47, 'Fatshark': 51, 'Spike Chunsoft Co.': 1, 'SEGA': 21, 'Clever Endeavour Games': 42, 'Trion Worlds': 44, 'Klonk Games': 50, 'Rebellion': 41, 'Axolot Games': 24, 'SUNFISH Co.': 45, 'Deck13': 48, '雷武游戏': 17, 'Introversion Software': 34, 'Feral interactive (Mac)': 16, 'Curve Digital': 29, 'Frozen District': 3, 'LuGus Studios': 35, 'Monomi Park': 26, 'Valve': 20, 'Ltd.': 2, 'FFF Bayern': 49, 'Ndemic Creations': 32, 'Studio 397': 36, 'WOLCEN Studio': 39, 'The Behemoth': 13, 'NEOBRICKS': 53, 'Codon': 27, 'NS STUDIO': 52, 'Paradise Project': 9, 'Wevr': 23, '1C-SoftClub': 30, 'Square Enix': 6, 'Ubisoft': 7, 'Unknown Worlds Entertainment': 43}

# %%
connect.close()
